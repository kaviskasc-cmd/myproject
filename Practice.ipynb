# %%
name='Kavitha'
age=34
print(name,age)
print("My name is", name,".","I am",age,"years old")
# Out:
# Kavitha 34
# My name is Kavitha . I am 34 years old

# %%
num=int(input("enter a number:"))
if num % 2 == 0:
         print("Even")
else:
         print("odd")
# Out:
# enter a number: 24
# Even

# %%
a=int(input("enter 1st number"))
b=int(input("enter 2nd number"))
a,b=b,a
print("a=",a)
print("b=",b)
# Out:
# enter 1st number 22
# enter 2nd number 21
# a= 21
# b= 22

# %%
a=4
b=3
c=7
a,b,c=b,c,a
print("a=",a)
print("b=",b)
print("c=",c)
# Out:
# a= 3
# b= 7
# c= 4

# %%
Celsius=float(input("enter the number"))
farenheit=9/5*Celsius+32
print("Temperature in farenheit:",farenheit)
# Out:
# enter the number 34
# Temperature in farenheit: 93.2

# %%
sales = [200, 450, 300, 150, 500]
total=sum(sales)
average=total/len(sales)
maximum=max(sales)
print("total Sales=", total)
print("Average=", average)
print("Maximum Sales=",maximum)
# Out:
# total Sales= 1600
# Average= 320.0
# Maximum Sales= 500

# %%
data = [10, 20, 20, 30, 40, 40, 50]
unique_data=list(set(data))
print(unique_data)
# Out:
# [40, 10, 50, 20, 30]

# %%
marks = {"A": 80, "B": 65, "C": 90}
maximum=max(marks, key=marks.get)
print("marks",marks[maximum])
print("high scorer:",maximum)
# Out:
# marks 90
# high scorer: C

# %%
s="   Hello World   "
s.strip().lower()
# Out:
# 'hello world'

# %%
s.

# %%
y="python is easy"
s=y.split()
s
# Out:
# ['python', 'is', 'easy']

# %%
s.reverse()
s
# Out:
# ['python', 'is', 'easy']

# %%
result=" ".join(s)
result
# Out:
# 'python is easy'

# %%
s = input("Enter a sentence: ")

words = s.split()        # split into words
words.reverse()          # reverse list

result = " ".join(words) # join back to string

print(result)
# Out:
# Enter a sentence:  python is easy
# easy is python

# %%
s=input("enter a sentence:")
result=" ".join(s.split()[::-1])
print(result)
# Out:
# enter a sentence: how are you
# you are how

# %%
s=input("enter a string:")
freq=Counter()
freq
# Out:
# enter a string: name
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 s=input("enter a string:")
# ----> 2 freq=Counter()
#       3 freq
#
# NameError: name 'Counter' is not defined

# %%
s = input("Enter a string: ")

result = ""

for ch in s:
    if ch not in result:
        result += ch

print("Output:", result)
# Out:
# Enter a string:  coffee
# Output: cofe

# %%
names = ["  Alice ", "BOB", "ChArLiE  "]
cleaned_names = []
for name in names:
    clean_name = name.strip().title()
    cleaned_names.append(clean_name)
print(cleaned_names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
num=int(input("enter the number:"))
if num % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# enter the number: 32
# Even

# %%
names = ["  Alice ", "BOB", "ChArLiE  "]
cleaned=[name.strip().title() for name in names]
print(cleaned)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
names = ["  Alice ", "BOB", "ChArLiE  "]
cleaned_names = []
for name in names:
     clean_name = name.strip().title()
     cleaned_names.append(clean_name)
print(cleaned_names)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
s=int(input("enter the number:"))
if s % 2 ==0:
    print("Even")
else:
    print("odd")
# Out:
# enter the number: 23
# odd

# %%
s=input("enter a string:")
if s == s[::-1]:
   print("palindrome")
else:
   print("not palindrome")
# Out:
# enter a string: note book
# not palindrome

# %%
nums = [1, 2, 2, 3, 4, 4, 5]
nums=list(set(nums))
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
nums = [1, 2, 2, 3, 4, 4, 5]
unique=[]
for n in nums:
    if n not in unique:
        unique.append(n)
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
nums = [5, 3, 5, 2, 3, 1]
nums=list(dict.fromkeys(nums))
print(nums)
# Out:
# [5, 3, 2, 1]

# %%
nums = [10, 20, 4, 45, 99]
nums=list(set(nums))
nums.sort()
print("second largest number is",nums[-2])
# Out:
# second largest number is 45

# %%
nums = [12, 35, 1, 10, 34, 1]
nums=list(set(nums))
nums.sort()
print("second largest number:",nums[-2])
# Out:
# second largest number: 34

# %%
nums = [12, 35, 1, 10, 34, 1]

print("second largest number:",sorted(set(nums))[-2])
# Out:
# second largest number: 34

# %%
nums = [12, 35, 1, 10, 34, 1]
nums=list(set(nums))
nums.sort()
print("second largest number:",nums[-2])
# Out:
# second largest number: 34

# %%
nums = [12, 35, 1, 10, 34, 1]
unique=sorted(set(nums))
if len(unique)<2:
    print("no second largest number")
else:
    print("second largest number:",unique[-2])
# Out:
# second largest number: 34

# %%
nums = [4, 2, 7, 7, 5, 2, 9]
nums=list(set(nums))
nums.sort()
print("Largest number:",nums[-1])
print("second largest number:",nums[-2])
print("third largest number:",nums[-3])
# Out:
# Largest number: 9
# second largest number: 7
# third largest number: 5

# %%
nums = [4, 2, 7, 7, 5, 2, 9]
x=sorted(set(nums),reverse=True)
print(x[:3])
# Out:
# [9, 7, 5]

# %%
nums = [4, 2, 7, 7, 5, 2, 9]
nums=list(set(nums))
nums.sort()
if len(nums)<3:
    print("no unique number")
else:
    print("Largest number:",nums[-1])
    print("second largest number:",nums[-2])
    print("third largest number:",nums[-3])
# Out:
# Largest number: 9
# second largest number: 7
# third largest number: 5

# %%
nums = [0, 1, 0, 3, 12]
results=[]
for n in nums:
 if n!=0:
    results.append(n)
for n in nums:
 if n==0:
    results.append(n)
print(results)
# Out:
# [1, 3, 12, 0, 0]

# %%
nums = [0, 0, 5, 2]
result=[]
for n in nums:
    if n!=0:
        result.append(n)
for n in nums:
    if n==0:
        result.append(n)
print(result)
# Out:
# [5, 2, 0, 0]

# %%
nums = [1, 2, 3, 1, 2, 4]
seen = set()
duplicates = []

for n in nums:
    if n in seen:
        duplicates.append(n)
    else:
        seen.add(n)

print(duplicates)
# Out:
# [1, 2]

# %%
nums = [4, 5, 6, 4, 7, 5, 8]
seen=set()
duplicate=[]
for n in nums:
    if n in seen:
        duplicate.append(n)
    else:
        seen.add(n)
print(duplicate)
# Out:
# [4, 5]

# %%
nums = [1, 2, 2, 3, 4, 4, 5]
unique=[]
for n in nums:
    if n not in unique:
        unique.append(n)
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
unique=list(dict.fromkeys(nums))
print(unique)
# Out:
# [1, 2, 3, 4, 5]

# %%
#Intersection
a = [1, 2, 3, 4]
b = [3, 4, 5, 6]
result=list(set(a)&set(b))
print(result)
# Out:
# [3, 4]

# %%
a = [1, 2, 2, 3]
b = [2, 2, 4]
unique=list(set(a)&set(b))
print(unique)
# Out:
# [2]

# %%
a = [1, 2, 3, 4]
b = [3, 4]
unique=list(set(a)-set(b))
print(unique)
# Out:
# [1, 2]

# %%
result=[]
for n in a:
    if n not in b:
        result.append(n)
print(result)
# Out:
# [1, 2]

# %%
a = [1, 2, 3]
b = [3, 4, 5]
result=[]
for n in a:
    if n not in b:
        result.append(n)
for n in b:
    if n not in a:
        result.append(n)
        
print(result)
# Out:
# [1, 2, 4, 5]

# %%
result=list(set(a)^set(b))
print(result)
# Out:
# [1, 2, 4, 5]

# %%
#Check if a string is a palindrome.
n=input("enter a word")
if n == n[::-1]:
    print("It is a absolute palindrome")
else:
    print("sorry! it is not")
# Out:
# enter a word sorry
# sorry! it is not

# %%
#check positive,negative and zero
you=input("Enter a number")
if you > 0:
    print("Positive")

elif you < 0:
    print("Negative")

else:
    print("Zero")
# Out:
# Enter a number 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 #check positive,negative and zero
#       2 you=input("Enter a number")
# ----> 3 if you > 0:
#       4     print("Positive")
#       5
#       6 elif you < 0:
#
# TypeError: '>' not supported between instances of 'str' and 'int'
